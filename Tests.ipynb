# %%
# !pip install csv2sqltable -U
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for csv2sqltable: filename=csv2sqltable-0.0.4-py3-none-any.whl size=2259 sha256=fdceaedbdc515b70c86a684ca898524cef55769ad96f471ddb401f3b1bfb6824
#   Stored in directory: /root/.cache/pip/wheels/83/9c/38/f1c215a2950618ba2cbff9ce9a04c221b1fbc67701176111be
# Successfully built csv2sqltable
# ...

# %%
# !pip install "SQLAlchemy<1.4"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 48.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for SQLAlchemy: filename=SQLAlchemy-1.3.24-cp310-cp310-linux_x86_64.whl size=1268250 sha256=77bcce431f6750e4292e1b65fbb946854acf0886a65ca129835e49d35ab39f9e
#   Stored in directory: /root/.cache/pip/wheels/27/51/b3/3481e88d5a5ba95dd4aafedc9316774d941c4ba61cfb93add8
# Successfully built SQLAlchemy
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.16
#     Uninstalling SQLAlchemy-2.0.16:
#       Successfully uninstalled SQLAlchemy-2.0.16
# ...

# %%
# %reload_ext sql

# %%
# %%sql sqlite:///vicks.db

# %%
import csv2sqltable.convert as c2s

# %%
print(c2s.transform('CSVs/emp.csv'))
# Out:
# %%sql
# /*
# !pip install "SQLAlchemy<1.4"
#
# %reload_ext sql
#
# %%sql sqlite:///vicks.db
# */
#
# -- DROP TABLE CSVs/emp;
#
# CREATE TABLE CSVs/emp (
# emp_no VARCHAR(100),
# fname VARCHAR(100),
# sal VARCHAR(100),
# age VARCHAR(100),
#
# );
#
# )
# VALUES
# ),
# ),
# ),
# ),
# ),
# ),
# ),
# ),
# ),
# ),
# ;
#
# SELECT * FROM CSVs/emp;

# %%
import os
os.listdir('CSVs')
# Out:
# ['customer.csv',
#  'Products.csv',
#  'student_details.csv',
#  'B-Tech Students.csv',
#  'studentinfo.csv',
#  'SSN_Employee.csv',
#  'student groupby.csv',
#  'student.csv',
#  'emp.csv',
#  'TA.csv',
#  'customer aliases.csv',
#  'Customer Order.csv',
#  'OrderDetails.csv',
#  'employee.csv',
#  'Update Customer.csv',
#  'student union.csv',
#  'primary student.csv',
#  'suppliers.csv',
#  'student_contact.csv',
#  'studentcourse.csv',
#  'students order.csv',
#  'Customers.csv',
#  'instructor.csv',
#  'studentcourse leftjoin.csv']

# %%
import time

# %%
t1 = time.time()

for i in os.listdir('.'):
  try:
    print(c2s.transform(i))
    print('\n', '-'*70, end='\n\n')
  except:
    pass

t2 = time.time()
# Out:
# %%sql
# /*
# !pip install "SQLAlchemy<1.4"
#
# %reload_ext sql
#
# %%sql sqlite:///vicks.db
# */
#
# -- DROP TABLE customer;
#
# CREATE TABLE customer (
# customer_id VARCHAR(100),
# customername VARCHAR(100),
# lastname VARCHAR(100),
# country VARCHAR(100),
# age VARCHAR(100),
# phone VARCHAR(100),
#
# );
#
# )
# VALUES
# ),
# ),
# ),
# ),
# ),
# ;
#
# SELECT * FROM customer;
#
#  ----------------------------------------------------------------------
#
# %%sql
# /*
# !pip install "SQLAlchemy<1.4"
#
# %reload_ext sql
#
# %%sql sqlite:///vicks.db
# */
#
# -- DROP TABLE Products;
#
# CREATE TABLE Products (
# ProductID VARCHAR(100),
# ProductName VARCHAR(100),
# SupplierID VARCHAR(100),
# CategoryID VARCHAR(100),
# Price VARCHAR(100),
#
# );
#
# )
# VALUES
# ),
# ),
# ),
# ),
# ),
# ),
# ),
# ),
# ),
# ;
#
# SELECT * FROM Products;
#
#  ----------------------------------------------------------------------
#
# %%sql
# /*
# !pip install "SQLAlchemy<1.4"
#
# %reload_ext sql
#
# ...

# %%
t2 - t1
# Out:
# 0.1396195888519287

# %% [markdown]
#     Time I took to write this much manually was > 1 hour, so yes it's helpful

# %%
# %%sql
# /*
# !pip install "SQLAlchemy<1.4"
#
# %reload_ext sql
#
# %%sql sqlite:///vicks.db
# */
#
# -- DROP TABLE employee;
#
# CREATE TABLE employee (
# employee_id VARCHAR(100),
# employee_name VARCHAR(100),
# salary VARCHAR(100)
# );
#
# INSERT INTO employee (employee_id, employee_name, salary)
# VALUES
# ('1', 'Shubham', '25000'),
# ('2', 'Aman', '55100'),
# ('3', 'Naveen', '52100'),
# ('4', 'Aditya', '12412'),
# ('5', 'Nishant', '62202');
#
# SELECT * FROM employee;
# Out:
#  * sqlite:///vicks.db
# Done.
# 5 rows affected.
# Done.
# [('1', 'Shubham', '25000'),
#  ('2', 'Aman', '55100'),
#  ('3', 'Naveen', '52100'),
#  ('4', 'Aditya', '12412'),
#  ('5', 'Nishant', '62202')]
